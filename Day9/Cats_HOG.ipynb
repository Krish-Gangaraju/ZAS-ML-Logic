# %%
import matplotlib.pyplot as plt

from skimage.feature import hog
from skimage import data, exposure

# %%
image = data.astronaut()

fd, hog_image = hog(image, orientations=8, pixels_per_cell=(16, 16),
                    cells_per_block=(1, 1), visualize=True, multichannel=True)

# %% [raw]
# fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(8, 4), sharex=True, sharey=True)
#
# ax1.axis('off')
# ax1.imshow(image, cmap=plt.cm.gray)
# ax1.set_title('Input image')
#
# # Rescale histogram for better display
# hog_image_rescaled = exposure.rescale_intensity(hog_image, in_range=(0, 10))
#
# ax2.axis('off')
# ax2.imshow(hog_image_rescaled, cmap=plt.cm.gray)
# ax2.set_title('Histogram of Oriented Gradients')
# plt.show()

# %%
from skimage import io

# %%
from skimage.transform import rescale, resize, downscale_local_mean

# %%
cat1 = io.imread("cat1.jpg")
cat2 = io.imread("cat2.jpg")
cat3 = io.imread("cat3.jpg")
cat4 = io.imread("cat4.jpg")
cat5 = io.imread("cat5.jpg")
cat6 = io.imread("cat6.jpg")

# %%
plt.imshow(cat1_resized)

# %%
fig, axs = plt.subplots(3, 2,figsize=(8,8))
axs[0, 0].imshow(cat1)
axs[0, 1].imshow(cat2)
axs[1, 0].imshow(cat3)
axs[1, 1].imshow(cat4)
axs[2, 0].imshow(cat5)
axs[2, 1].imshow(cat6)

# %%
cat1_resized = resize(cat1, (250, 250),
                       anti_aliasing=True)

cat2_resized = resize(cat2, (250, 250),
                       anti_aliasing=True)

cat3_resized = resize(cat3, (250, 250),
                       anti_aliasing=True)

cat4_resized = resize(cat4, (250, 250),
                       anti_aliasing=True)

cat5_resized = resize(cat5, (250, 250),
                       anti_aliasing=True)

cat6_resized = resize(cat6, (250, 250),
                       anti_aliasing=True)

# %%
plt.imshow(cat1_resized)

# %%
fig, axs = plt.subplots(3, 2,figsize=(8,8))
axs[0, 0].imshow(cat1_resized)
axs[0, 1].imshow(cat2_resized)
axs[1, 0].imshow(cat3_resized)
axs[1, 1].imshow(cat4_resized)
axs[2, 0].imshow(cat5_resized)
axs[2, 1].imshow(cat6_resized)

# %%
fd_1, cat1_hog_image = hog(cat1_resized, orientations=8, pixels_per_cell=(16, 16),
                    cells_per_block=(1, 1), visualize=True, multichannel=True)

fd_2, cat2_hog_image = hog(cat2_resized, orientations=8, pixels_per_cell=(16, 16),
                    cells_per_block=(1, 1), visualize=True, multichannel=True)

fd_3, cat3_hog_image = hog(cat3_resized, orientations=8, pixels_per_cell=(16, 16),
                    cells_per_block=(1, 1), visualize=True, multichannel=True)

fd_4, cat4_hog_image = hog(cat4_resized, orientations=8, pixels_per_cell=(16, 16),
                    cells_per_block=(1, 1), visualize=True, multichannel=True)

fd_5, cat5_hog_image = hog(cat5_resized, orientations=8, pixels_per_cell=(16, 16),
                    cells_per_block=(1, 1), visualize=True, multichannel=True)

fd_6, cat6_hog_image = hog(cat6_resized, orientations=8, pixels_per_cell=(16, 16),
                    cells_per_block=(1, 1), visualize=True, multichannel=True)

# %%
fig, axs = plt.subplots(3, 2,figsize=(8,8))
axs[0, 0].imshow(cat1_hog_image)
axs[0, 1].imshow(cat2_hog_image)
axs[1, 0].imshow(cat3_hog_image)
axs[1, 1].imshow(cat4_hog_image)
axs[2, 0].imshow(cat5_hog_image)
axs[2, 1].imshow(cat6_hog_image)
